# %% [markdown]
# ### Import relevant Libraries

# %%
from typing import Dict, List, Union, Callable
from datetime import datetime

from pyspark.sql import functions as F
from pyspark.sql.dataframe import DataFrame
from pyspark.sql.functions import from_unixtime, col, udf, col, current_date, datediff, floor
from pyspark.sql.types import StructField, StructType, StringType, DoubleType, LongType
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 3, Finished, Available, Finished)

# %% [markdown]
# ### Define the Sequence of Transformations
#
# All the steps that is performed on the `JSON` data in the `user_data` folder is defined here along with a `sequence_mapper` decorator that helps track the current state of the transformations

# %%
sequence_map = {
    "Step 1": "Read the JSON data from Abfss filepath as Complex Dataframe\n",
    "Step 2": "Extracting payload\n",
    "Step 3": "Flatten the payload\n",
    "Step 4": "Creating input DataFrame\n",
    "Step 5": "Capitalize column names\n",
    "Step 6": "Convert Timestamp column to Date and/or Datetime\n",
    "Step 7": "Extract and Create Timezone Location and offset from GMT fields\n",
    "Step 8": "Create float field from GMT offset field\n",
    "Step 9": "Extract and Create the Ages field\n",
    "Step 10": "Reorder the columns and add Ingestion Date field\n",
    "Step 11": "Writing the cleaned dataframe to Delta Table"
}

def sequence_mapper(step_val: str):
    """
    A decorator that prints the current step description from a predefined sequence map.

    This decorator can be applied to functions to provide contextual information 
    about the processing steps being executed. It retrieves the step description 
    corresponding to the provided `step_val` and prints it before calling the 
    decorated function.

    Parameters:
    step_val (str): The key in the sequence_map that corresponds to the current 
                    processing step. It should match one of the predefined keys 
                    in the sequence_map.

    Returns:
    function: The wrapped function that will be executed after the step description 
              is printed.
    """

    def decorator(func):
        """
        A helper function that wraps the original function with additional behavior.

        This function takes the original function and adds the functionality of 
        printing the step description from the sequence_map.

        Parameters:
        func (function): The original function to be decorated.

        Returns:
        function: A wrapper function that includes the step description print 
                  functionality.
        """
        
        def wrapper(*args, **kwargs):
            print(sequence_map[step_val])
            result = func(*args, **kwargs)
            return result
        
        return wrapper
    
    return decorator
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 4, Finished, Available, Finished)

# %% [markdown]
# ### Function Definitions
# This section defines all the functions used to perform the transformations. Each function has its own set of docstrings explaining what they do, along with the `sequence_mapper` decorator for tracking. The functions used here are:
# 1. **read_data**
# 2. **extract_payload**
# 3. **parse_payload**
# 4. **create_schema**
# 5. **create_dataframe_from_parsed_payload**
# 6. **capitalize_columns**
# 7. **parse_timestamps**
# 8. **split_timezone**
# 9. **timezone_hours_from_gmt**
# 10. **extract_age**
# 11. **final_cleanup**
# 12. **write_to_delta**

# %%
@sequence_mapper("Step 1")
def read_data(abfss_path: str)->DataFrame:
    """
    Reads JSON data from the specified ABFSS filepath into a Spark DataFrame.

    This function reads a JSON file from the specified Azure Blob Storage 
    File System (ABFSS) path and returns the data as a Spark DataFrame.

    Parameters:
    abfss_path (str): The path to the JSON file in the ABFSS.

    Returns:
    DataFrame: A Spark DataFrame containing the data read from the JSON file.
    """

    df = spark.read.option("multiline", "true").json(abfss_path)
    return df

abfss_path = "abfss://fabric_cdc@onelake.dfs.fabric.microsoft.com/cdc_lakehouse.Lakehouse/Files/user_folder"
df = read_data(abfss_path)
display(df)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 5, Finished, Available, Finished)
# Read the JSON data from Abfss filepath as Complex Dataframe
# SynapseWidget(Synapse.DataFrame, e6423d48-3f7f-4a44-9922-c42c3a71af0b)

# %%
@sequence_mapper("Step 2")
def extract_payload(df: DataFrame)-> List:
    """
    Extracts the payload from a Spark DataFrame by dropping unnecessary columns 
    and converting it to a list of dictionaries.

    This function removes the "schema" column from the DataFrame and converts 
    the resulting DataFrame to a list of dictionaries, where each dictionary 
    represents a record.

    Parameters:
        df (DataFrame): The input Spark DataFrame from which to extract the payload.

    Returns:
        List: A list of dictionaries containing the payload data, with each 
              dictionary corresponding to a record in the DataFrame.
    """

    payload_df = df.drop("schema")
    payload_array = payload_df.toPandas().to_dict(orient = "records")
    return payload_array

payload_array: List = extract_payload(df)
payload_array
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 6, Finished, Available, Finished)
# Extracting payload
# [{'payload': {'after': {'address': '3973 دکتر لواسانی, ایلام, آذربایجان شرقی - Iran 86952',
#     'cell': '0943-252-6704',
#     'date_of_birth': 201271548020000,
#     'email': 'yly.qsmy@example.com',
#     'gender': 'male',
#     'id': 1140,
#     'insertion_time': 1727516957704587,
#     'latitude': 15.2516,
#     'longitude': -101.2421,
#     'name': 'Mr ایلیا قاسمی',
#     'phone': '023-98186430',
#     'picture_url': 'https://randomuser.me/api/portraits/men/87.jpg',
#     'registered_date': 1353356496219000,
#     'timezone': 'Newfoundland (Offset -3:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934087296,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934086952","70934087296"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516958411,
#     'txId': 293345,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516958995}},
#  {'payload': {'after': {'address': '481 میدان شهید نامجو, گلستان, همدان - Iran 85172',
#     'cell': '0940-082-0998',
#     'date_of_birth': -198406119041000,
#     'email': 'drs.glshn@example.com',
#     'gender': 'female',
#     'id': 1232,
#     'insertion_time': 1727517601179488,
#     'latitude': 15.3702,
#     'longitude': 135.9397,
#     'name': 'Mrs درسا گلشن',
#     'phone': '069-40685324',
#     'picture_url': 'https://randomuser.me/api/portraits/women/80.jpg',
#     'registered_date': 1464859315038000,
#     'timezone': 'Magadan, Solomon Islands, New Caledonia (Offset +11:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967649496,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967649296","70967649496"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517601851,
#     'txId': 293586,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517602354}},
#  {'payload': {'after': {'address': '9916 آیت\u200cالله سعیدی, یزد, یزد - Iran 66272',
#     'cell': '0916-200-4457',
#     'date_of_birth': -113026886301000,
#     'email': 'yly.glshn@example.com',
#     'gender': 'male',
#     'id': 1228,
#     'insertion_time': 1727517575333393,
#     'latitude': 15.3326,
#     'longitude': -178.459,
#     'name': 'Mr ایلیا گلشن',
#     'phone': '063-34878922',
#     'picture_url': 'https://randomuser.me/api/portraits/men/19.jpg',
#     'registered_date': 1516065422789000,
#     'timezone': 'Central Time (US & Canada), Mexico City (Offset -6:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967646528,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967646224","70967646528"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517576071,
#     'txId': 293576,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517576607}},
#  {'payload': {'after': {'address': '3901 پاسداران, شیراز, گیلان - Iran 25970',
#     'cell': '0980-135-8669',
#     'date_of_birth': 464853156763000,
#     'email': 'zhr.nkwnzr@example.com',
#     'gender': 'female',
#     'id': 1098,
#     'insertion_time': 1727516674977987,
#     'latitude': 16.9944,
#     'longitude': 89.5298,
#     'name': 'Ms زهرا نكو نظر',
#     'phone': '025-95331192',
#     'picture_url': 'https://randomuser.me/api/portraits/women/74.jpg',
#     'registered_date': 1131320306753000,
#     'timezone': 'Almaty, Dhaka, Colombo (Offset +6:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917393728,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917393328","70917393728"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516675661,
#     'txId': 293239,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516676084}},
#  {'payload': {'after': {'address': '638 جلال آل احمد, اصفهان, فارس - Iran 58146',
#     'cell': '0913-675-2504',
#     'date_of_birth': 467027930533000,
#     'email': 'aaly.nkwnzr@example.com',
#     'gender': 'male',
#     'id': 1159,
#     'insertion_time': 1727517082827669,
#     'latitude': 17.3349,
#     'longitude': -100.9254,
#     'name': 'Mr علی نكو نظر',
#     'phone': '053-89305077',
#     'picture_url': 'https://randomuser.me/api/portraits/men/54.jpg',
#     'registered_date': 1550435944499000,
#     'timezone': 'Newfoundland (Offset -3:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934103992,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934103592","70934103992"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517083606,
#     'txId': 293394,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517083980}},
#  {'payload': {'after': {'address': '4299 موسیوند, تهران, مرکزی - Iran 84475',
#     'cell': '0939-818-1505',
#     'date_of_birth': -34945689159000,
#     'email': 'mny.hydry@example.com',
#     'gender': 'male',
#     'id': 1105,
#     'insertion_time': 1727516726969541,
#     'latitude': 15.7855,
#     'longitude': -24.7915,
#     'name': 'Mr مانی حیدری',
#     'phone': '028-62020806',
#     'picture_url': 'https://randomuser.me/api/portraits/men/43.jpg',
#     'registered_date': 1297685704418000,
#     'timezone': 'Azores, Cape Verde Islands (Offset -1:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917399000,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917398856","70917399000"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516727691,
#     'txId': 293257,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516728244}},
#  {'payload': {'after': {'address': '7804 Continuación Grecia, Santiago Miahuatlán, Campeche - Mexico 45181',
#     'cell': '(650) 873 6248',
#     'date_of_birth': -765996719562000,
#     'email': 'margarita.menendez@example.com',
#     'gender': 'female',
#     'id': 1102,
#     'insertion_time': 1727516704383049,
#     'latitude': 24.9954,
#     'longitude': 139.0585,
#     'name': 'Ms Margarita Menéndez',
#     'phone': '(678) 436 3909',
#     'picture_url': 'https://randomuser.me/api/portraits/women/87.jpg',
#     'registered_date': 1280710567716000,
#     'timezone': 'Central Time (US & Canada), Mexico City (Offset -6:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917396832,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917396232","70917396832"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516705121,
#     'txId': 293250,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516705399}},
#  {'payload': {'after': {'address': '9414 Callejón Sur Vaca, San Mateo Otzacatipan, Oaxaca - Mexico 98595',
#     'cell': '(687) 704 0826',
#     'date_of_birth': -487735545085000,
#     'email': 'mariajose.verduzco@example.com',
#     'gender': 'female',
#     'id': 1235,
#     'insertion_time': 1727517645055311,
#     'latitude': 21.5431,
#     'longitude': 58.9114,
#     'name': 'Mrs María José Verduzco',
#     'phone': '(616) 439 0609',
#     'picture_url': 'https://randomuser.me/api/portraits/women/15.jpg',
#     'registered_date': 1261104843049000,
#     'timezone': 'Brussels, Copenhagen, Madrid, Paris (Offset +1:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967652792,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967652448","70967652792"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517645811,
#     'txId': 293599,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517646046}},
#  {'payload': {'after': {'address': '8962 Prolongación Norte Arce, Ejido La Victoria, Guanajuato - Mexico 59070',
#     'cell': '(612) 770 0090',
#     'date_of_birth': -499620990717000,
#     'email': 'leonel.castellanos@example.com',
#     'gender': 'male',
#     'id': 1107,
#     'insertion_time': 1727516739905263,
#     'latitude': 23.0699,
#     'longitude': -35.9012,
#     'name': 'Mr Leonel Castellanos',
#     'phone': '(622) 907 2088',
#     'picture_url': 'https://randomuser.me/api/portraits/men/69.jpg',
#     'registered_date': 1038344411934000,
#     'timezone': 'Eastern Time (US & Canada), Bogota, Lima (Offset -5:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917400448,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917400248","70917400448"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516740591,
#     'txId': 293262,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516740966}},
#  {'payload': {'after': {'address': '1516 Avenue du Fort-Caire, Solothurn, Appenzell Ausserrhoden - Switzerland 3570',
#     'cell': '075 982 63 21',
#     'date_of_birth': 347775935507000,
#     'email': 'vincenzo.rolland@example.com',
#     'gender': 'male',
#     'id': 1143,
#     'insertion_time': 1727516977072527,
#     'latitude': -64.0413,
#     'longitude': -65.1197,
#     'name': 'Monsieur Vincenzo Rolland',
#     'phone': '077 259 83 05',
#     'picture_url': 'https://randomuser.me/api/portraits/men/26.jpg',
#     'registered_date': 1069844336057000,
#     'timezone': 'Baghdad, Riyadh, Moscow, St. Petersburg (Offset +3:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934089752,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934089352","70934089752"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516977816,
#     'txId': 293353,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516978317}},
#  {'payload': {'after': {'address': '3553 Akademika Grushevskogo, Kipuche, Dnipropetrovska - Ukraine 89882',
#     'cell': '(066) X67-0172',
#     'date_of_birth': -720768230322000,
#     'email': 'zoreglyada.makushenko@example.com',
#     'gender': 'female',
#     'id': 1162,
#     'insertion_time': 1727517105923291,
#     'latitude': 77.849,
#     'longitude': 57.3779,
#     'name': 'Ms Zoreglyada Makushenko',
#     'phone': '(097) O67-1033',
#     'picture_url': 'https://randomuser.me/api/portraits/women/46.jpg',
#     'registered_date': 1527442203526000,
#     'timezone': 'Magadan, Solomon Islands, New Caledonia (Offset +11:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70950847552,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70950847152","70950847552"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517106576,
#     'txId': 293402,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517106881}},
#  {'payload': {'after': {'address': '4367 Nebojše Džukelića, Aleksandrovac, Kosovska Mitrovica - Serbia 83815',
#     'cell': '062-9036-580',
#     'date_of_birth': 226897156295000,
#     'email': 'leposava.tasic@example.com',
#     'gender': 'female',
#     'id': 1147,
#     'insertion_time': 1727517003311894,
#     'latitude': 56.9282,
#     'longitude': 36.5096,
#     'name': 'Ms Leposava Tasić',
#     'phone': '012-2283-329',
#     'picture_url': 'https://randomuser.me/api/portraits/women/37.jpg',
#     'registered_date': 1517674846767000,
#     'timezone': 'Abu Dhabi, Muscat, Baku, Tbilisi (Offset +4:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934092696,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934092352","70934092696"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517004031,
#     'txId': 293363,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517004609}},
#  {'payload': {'after': {'address': '3385 Avenida Vinícius de Morais, Ferraz de Vasconcelos, Paraná - Brazil 14758',
#     'cell': '(66) 1227-9743',
#     'date_of_birth': -308222018324000,
#     'email': 'nely.rezende@example.com',
#     'gender': 'female',
#     'id': 1213,
#     'insertion_time': 1727517477050646,
#     'latitude': -75.1048,
#     'longitude': 36.6019,
#     'name': 'Miss Nely Rezende',
#     'phone': '(95) 4974-4207',
#     'picture_url': 'https://randomuser.me/api/portraits/women/47.jpg',
#     'registered_date': 1334077680378000,
#     'timezone': 'Azores, Cape Verde Islands (Offset -1:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967635360,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967634968","70967635360"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517477691,
#     'txId': 293539,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517477976}},
#  {'payload': {'after': {'address': '190 Manchester Road, Salisbury, Mid Glamorgan - United Kingdom BH06 6JH',
#     'cell': '07486 775582',
#     'date_of_birth': -500054220509000,
#     'email': 'herman.howard@example.com',
#     'gender': 'male',
#     'id': 1255,
#     'insertion_time': 1727517777779229,
#     'latitude': -10.7349,
#     'longitude': -87.1153,
#     'name': 'Mr Herman Howard',
#     'phone': '015395 50971',
#     'picture_url': 'https://randomuser.me/api/portraits/men/17.jpg',
#     'registered_date': 1651890271331000,
#     'timezone': 'Western Europe Time, London, Lisbon, Casablanca (Offset 0:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984410640,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984410192","70984410640"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517778521,
#     'txId': 293651,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517778875}},
#  {'payload': {'after': {'address': '2941 Travessa dos Martírios, Governador Valadares, Tocantins - Brazil 22545',
#     'cell': '(80) 9297-4366',
#     'date_of_birth': 721471159269000,
#     'email': 'joao.dias@example.com',
#     'gender': 'male',
#     'id': 1216,
#     'insertion_time': 1727517496598556,
#     'latitude': -78.3617,
#     'longitude': -136.3043,
#     'name': 'Mr João Dias',
#     'phone': '(41) 9325-4979',
#     'picture_url': 'https://randomuser.me/api/portraits/men/55.jpg',
#     'registered_date': 1634929957777000,
#     'timezone': 'Bombay, Calcutta, Madras, New Delhi (Offset +5:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967637688,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967637344","70967637688"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517497331,
#     'txId': 293547,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517497787}},
#  {'payload': {'after': {'address': '5933 Avenue du Fort-Caire, Nantes, Seine-Maritime - France 17024',
#     'cell': '06-11-29-89-72',
#     'date_of_birth': -230956622818000,
#     'email': 'yann.philippe@example.com',
#     'gender': 'male',
#     'id': 1153,
#     'insertion_time': 1727517042689745,
#     'latitude': -20.1421,
#     'longitude': -81.1349,
#     'name': 'Mr Yann Philippe',
#     'phone': '02-60-54-97-18',
#     'picture_url': 'https://randomuser.me/api/portraits/men/19.jpg',
#     'registered_date': 1622318507337000,
#     'timezone': 'Western Europe Time, London, Lisbon, Casablanca (Offset 0:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934099552,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934099208","70934099552"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517043391,
#     'txId': 293379,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517043836}},
#  {'payload': {'after': {'address': '9825 Atatürk Sk, Bitlis, Aksaray - Turkey 86046',
#     'cell': '(169)-997-5538',
#     'date_of_birth': 23101672488000,
#     'email': 'ulku.berberoglu@example.com',
#     'gender': 'female',
#     'id': 1196,
#     'insertion_time': 1727517356402860,
#     'latitude': 66.4394,
#     'longitude': 48.515,
#     'name': 'Ms Ülkü Berberoğlu',
#     'phone': '(989)-323-3680',
#     'picture_url': 'https://randomuser.me/api/portraits/women/64.jpg',
#     'registered_date': 1138219092269000,
#     'timezone': 'Eastern Time (US & Canada), Bogota, Lima (Offset -5:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70950883144,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70950879152","70950883144"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517357607,
#     'txId': 293493,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517358078}},
#  {'payload': {'after': {'address': '834 Rua José Bonifácio , Juiz de Fora, Amazonas - Brazil 45430',
#     'cell': '(92) 5815-5246',
#     'date_of_birth': -112511740394000,
#     'email': 'fabricio.darocha@example.com',
#     'gender': 'male',
#     'id': 1186,
#     'insertion_time': 1727517288799840,
#     'latitude': -80.0364,
#     'longitude': -13.8588,
#     'name': 'Mr Fabrício da Rocha',
#     'phone': '(73) 8441-8469',
#     'picture_url': 'https://randomuser.me/api/portraits/men/86.jpg',
#     'registered_date': 1498283642028000,
#     'timezone': 'Kaliningrad, South Africa (Offset +2:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70950866376,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70950866176","70950866376"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517289561,
#     'txId': 293468,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517290256}},
#  {'payload': {'after': {'address': '8524 Green Lane, Tramore, Dún Laoghaire–Rathdown - Ireland 31669',
#     'cell': '081-077-2344',
#     'date_of_birth': 699314298460000,
#     'email': 'chloe.oliver@example.com',
#     'gender': 'female',
#     'id': 1203,
#     'insertion_time': 1727517408537716,
#     'latitude': -1.332,
#     'longitude': 104.9289,
#     'name': 'Mrs Chloe Oliver',
#     'phone': '051-249-4136',
#     'picture_url': 'https://randomuser.me/api/portraits/women/59.jpg',
#     'registered_date': 1318130840335000,
#     'timezone': 'Baghdad, Riyadh, Moscow, St. Petersburg (Offset +3:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967625192,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967624792","70967625192"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517409591,
#     'txId': 293512,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517410373}},
#  {'payload': {'after': {'address': '7288 Rua Santo Antônio , Jaboatão dos Guararapes, Bahia - Brazil 78727',
#     'cell': '(93) 1007-2518',
#     'date_of_birth': -342185123452000,
#     'email': 'lisete.ramos@example.com',
#     'gender': 'female',
#     'id': 1207,
#     'insertion_time': 1727517438163357,
#     'latitude': -78.4996,
#     'longitude': 140.7156,
#     'name': 'Mrs Lisete Ramos',
#     'phone': '(48) 4447-6150',
#     'picture_url': 'https://randomuser.me/api/portraits/women/18.jpg',
#     'registered_date': 1375779044445000,
#     'timezone': 'Kaliningrad, South Africa (Offset +2:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967630616,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967630216","70967630616"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517438831,
#     'txId': 293523,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517439321}},
#  {'payload': {'after': {'address': '4831 Eje vial Morales, Las Guacamayas, Michoacan - Mexico 81522',
#     'cell': '(643) 935 9828',
#     'date_of_birth': 391127998499000,
#     'email': 'pablo.martinez@example.com',
#     'gender': 'male',
#     'id': 1217,
#     'insertion_time': 1727517503264687,
#     'latitude': 25.6161,
#     'longitude': -146.2405,
#     'name': 'Mr Pablo Martínez',
#     'phone': '(649) 691 7348',
#     'picture_url': 'https://randomuser.me/api/portraits/men/87.jpg',
#     'registered_date': 1291322800926000,
#     'timezone': 'Atlantic Time (Canada), Caracas, La Paz (Offset -4:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967638352,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967638208","70967638352"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517503921,
#     'txId': 293549,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517504133}},
#  {'payload': {'after': {'address': '7505 Corredor Beltrán, Nueva Concordia, Chihuahua - Mexico 66328',
#     'cell': '(613) 449 7076',
#     'date_of_birth': 173159444197000,
#     'email': 'homero.escobar@example.com',
#     'gender': 'male',
#     'id': 1253,
#     'insertion_time': 1727517764914768,
#     'latitude': 22.5729,
#     'longitude': -45.9044,
#     'name': 'Mr Homero Escobar',
#     'phone': '(690) 903 8602',
#     'picture_url': 'https://randomuser.me/api/portraits/men/1.jpg',
#     'registered_date': 1627536152136000,
#     'timezone': 'Eastern Time (US & Canada), Bogota, Lima (Offset -5:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984409112,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984408744","70984409112"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517765591,
#     'txId': 293645,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517765949}},
#  {'payload': {'after': {'address': '5518 Diagonal Oaxaca, Ignacio Ramírez, Estado de Mexico - Mexico 36677',
#     'cell': '(635) 707 6461',
#     'date_of_birth': -634989598137000,
#     'email': 'salvador.camarillo@example.com',
#     'gender': 'male',
#     'id': 1155,
#     'insertion_time': 1727517055531309,
#     'latitude': 26.2773,
#     'longitude': -153.6098,
#     'name': 'Mr Salvador Camarillo',
#     'phone': '(658) 122 5763',
#     'picture_url': 'https://randomuser.me/api/portraits/men/2.jpg',
#     'registered_date': 1021927980537000,
#     'timezone': 'Bangkok, Hanoi, Jakarta (Offset +7:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934100864,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934100664","70934100864"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517056301,
#     'txId': 293383,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517056768}},
#  {'payload': {'after': {'address': '3612 Forest Ln, Pomona, Tennessee - United States 62401',
#     'cell': '(973) 283-3273',
#     'date_of_birth': -772167651687000,
#     'email': 'herminia.hopkins@example.com',
#     'gender': 'female',
#     'id': 1227,
#     'insertion_time': 1727517568900165,
#     'latitude': 82.1507,
#     'longitude': 158.2535,
#     'name': 'Mrs Herminia Hopkins',
#     'phone': '(230) 436-3840',
#     'picture_url': 'https://randomuser.me/api/portraits/women/25.jpg',
#     'registered_date': 1195241512249000,
#     'timezone': 'Ekaterinburg, Islamabad, Karachi, Tashkent (Offset +5:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967645752,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967645408","70967645752"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517569631,
#     'txId': 293574,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517570018}},
#  {'payload': {'after': {'address': '6846 Vilitna, Vinnicya, Ternopilska - Ukraine 39987',
#     'cell': '(066) P27-4037',
#     'date_of_birth': -298892018779000,
#     'email': 'tetyana.chaykovskiy@example.com',
#     'gender': 'female',
#     'id': 1233,
#     'insertion_time': 1727517629751668,
#     'latitude': 79.4988,
#     'longitude': 68.6441,
#     'name': 'Miss Tetyana Chaykovskiy',
#     'phone': '(099) H41-5269',
#     'picture_url': 'https://randomuser.me/api/portraits/women/96.jpg',
#     'registered_date': 1084089763191000,
#     'timezone': 'Eastern Time (US & Canada), Bogota, Lima (Offset -5:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967651128,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967649984","70967651128"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517630391,
#     'txId': 293593,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517630545}},
#  {'payload': {'after': {'address': '3912 Ðorđa Milovanovića, Ruma, Zaječar - Serbia 79187',
#     'cell': '062-1484-660',
#     'date_of_birth': 943016532243000,
#     'email': 'ljiljana.terzic@example.com',
#     'gender': 'female',
#     'id': 1112,
#     'insertion_time': 1727516772314725,
#     'latitude': 57.1169,
#     'longitude': 46.0091,
#     'name': 'Miss Ljiljana Terzić',
#     'phone': '014-7415-773',
#     'picture_url': 'https://randomuser.me/api/portraits/women/5.jpg',
#     'registered_date': 1309531855049000,
#     'timezone': 'Azores, Cape Verde Islands (Offset -1:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917409320,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917408976","70917409320"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516772961,
#     'txId': 293275,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516773297}},
#  {'payload': {'after': {'address': '3866 Sjællandsgade, Skaerbaek, Midtjylland - Denmark 49822',
#     'cell': '79019710',
#     'date_of_birth': 837982399853000,
#     'email': 'filippa.jorgensen@example.com',
#     'gender': 'female',
#     'id': 1248,
#     'insertion_time': 1727517732254742,
#     'latitude': -40.7121,
#     'longitude': 141.4956,
#     'name': 'Ms Filippa Jørgensen',
#     'phone': '69050127',
#     'picture_url': 'https://randomuser.me/api/portraits/women/58.jpg',
#     'registered_date': 1386772676178000,
#     'timezone': 'Atlantic Time (Canada), Caracas, La Paz (Offset -4:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984405360,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984405104","70984405360"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517732961,
#     'txId': 293632,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517733615}},
#  {'payload': {'after': {'address': '733 Groveland Terrace, Townsville, New South Wales - Australia 3387',
#     'cell': '0471-932-741',
#     'date_of_birth': 903649428945000,
#     'email': 'lesa.richards@example.com',
#     'gender': 'female',
#     'id': 1136,
#     'insertion_time': 1727516931666420,
#     'latitude': -86.0874,
#     'longitude': 57.2256,
#     'name': 'Mrs Lesa Richards',
#     'phone': '05-8383-9596',
#     'picture_url': 'https://randomuser.me/api/portraits/women/38.jpg',
#     'registered_date': 1461328008744000,
#     'timezone': 'Atlantic Time (Canada), Caracas, La Paz (Offset -4:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934084384,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934084128","70934084384"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516932392,
#     'txId': 293335,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516932914}},
#  {'payload': {'after': {'address': '4073 Mühlenweg, Oberhof, Schleswig-Holstein - Germany 47830',
#     'cell': '0175-1299726',
#     'date_of_birth': -146428707657000,
#     'email': 'sophia.mezger@example.com',
#     'gender': 'female',
#     'id': 1188,
#     'insertion_time': 1727517301684734,
#     'latitude': -50.7656,
#     'longitude': 154.112,
#     'name': 'Miss Sophia Mezger',
#     'phone': '0761-3924497',
#     'picture_url': 'https://randomuser.me/api/portraits/women/62.jpg',
#     'registered_date': 1032908777963000,
#     'timezone': 'Eastern Time (US & Canada), Bogota, Lima (Offset -5:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70950867688,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70950867432","70950867688"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517302436,
#     'txId': 293472,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517302719}},
#  {'payload': {'after': {'address': "7924 Place de L'Abbé-Basset, Brest, Aube - France 11301",
#     'cell': '06-38-60-09-97',
#     'date_of_birth': 562259232929000,
#     'email': 'valentine.giraud@example.com',
#     'gender': 'female',
#     'id': 1256,
#     'insertion_time': 1727517784206722,
#     'latitude': -18.7621,
#     'longitude': 77.5857,
#     'name': 'Miss Valentine Giraud',
#     'phone': '04-71-51-76-76',
#     'picture_url': 'https://randomuser.me/api/portraits/women/41.jpg',
#     'registered_date': 1104210213184000,
#     'timezone': 'Brussels, Copenhagen, Madrid, Paris (Offset +1:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984411264,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984411120","70984411264"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517784851,
#     'txId': 293653,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517785818}},
#  {'payload': {'after': {'address': '8704 Brick Kiln Road, Derby, Buckinghamshire - United Kingdom YN86 3LS',
#     'cell': '07850 257861',
#     'date_of_birth': 838505763143000,
#     'email': 'melissa.bates@example.com',
#     'gender': 'female',
#     'id': 1118,
#     'insertion_time': 1727516812927036,
#     'latitude': -12.4547,
#     'longitude': 61.5794,
#     'name': 'Mrs Melissa Bates',
#     'phone': '015396 66521',
#     'picture_url': 'https://randomuser.me/api/portraits/women/19.jpg',
#     'registered_date': 1135274550299000,
#     'timezone': 'Bombay, Calcutta, Madras, New Delhi (Offset +5:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934070944,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934070600","70934070944"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516813601,
#     'txId': 293290,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516813958}},
#  {'payload': {'after': {'address': '9025 Øster Alle, Århus C., Hovedstaden - Denmark 59306',
#     'cell': '34494660',
#     'date_of_birth': -172746868077000,
#     'email': 'caroline.sorensen@example.com',
#     'gender': 'female',
#     'id': 1165,
#     'insertion_time': 1727517145364185,
#     'latitude': -45.0337,
#     'longitude': 59.8655,
#     'name': 'Mrs Caroline Sørensen',
#     'phone': '48801681',
#     'picture_url': 'https://randomuser.me/api/portraits/women/44.jpg',
#     'registered_date': 1198174307498000,
#     'timezone': 'Bombay, Calcutta, Madras, New Delhi (Offset +5:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70950850672,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70950850272","70950850672"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517146152,
#     'txId': 293414,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517146752}},
#  {'payload': {'after': {'address': '8218 Bağdat Cd, Gümüşhane, Sivas - Turkey 89975',
#     'cell': '(003)-403-1442',
#     'date_of_birth': 231769308567000,
#     'email': 'fatma.sozeri@example.com',
#     'gender': 'female',
#     'id': 1189,
#     'insertion_time': 1727517308154710,
#     'latitude': 67.1358,
#     'longitude': 107.0242,
#     'name': 'Mrs Fatma Sözeri',
#     'phone': '(741)-187-1429',
#     'picture_url': 'https://randomuser.me/api/portraits/women/1.jpg',
#     'registered_date': 1504906350321000,
#     'timezone': 'Abu Dhabi, Muscat, Baku, Tbilisi (Offset +4:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70950868504,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70950868160","70950868504"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517308821,
#     'txId': 293475,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517309303}},
#  {'payload': {'after': {'address': '8770 Fatih Sultan Mehmet Cd, Iğdır, Kocaeli - Turkey 97658',
#     'cell': '(802)-171-9009',
#     'date_of_birth': -788784104095000,
#     'email': 'ali.ozberk@example.com',
#     'gender': 'male',
#     'id': 1215,
#     'insertion_time': 1727517490095256,
#     'latitude': 71.4579,
#     'longitude': -4.6093,
#     'name': 'Mr Ali Özberk',
#     'phone': '(272)-704-3548',
#     'picture_url': 'https://randomuser.me/api/portraits/men/79.jpg',
#     'registered_date': 1423377558253000,
#     'timezone': 'Baghdad, Riyadh, Moscow, St. Petersburg (Offset +3:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967636888,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967636688","70967636888"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517490781,
#     'txId': 293544,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517491202}},
#  {'payload': {'after': {'address': '6006 Øvre Ullern terrasse, Renbygda, Sør-Trøndelag - Norway 4664',
#     'cell': '44585777',
#     'date_of_birth': -136512348079000,
#     'email': 'herkus.hervik@example.com',
#     'gender': 'male',
#     'id': 1242,
#     'insertion_time': 1727517693250239,
#     'latitude': 41.4779,
#     'longitude': -56.8445,
#     'name': 'Mr Herkus Hervik',
#     'phone': '21249111',
#     'picture_url': 'https://randomuser.me/api/portraits/men/2.jpg',
#     'registered_date': 1198556474460000,
#     'timezone': 'Atlantic Time (Canada), Caracas, La Paz (Offset -4:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984401080,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967757192","70984401080"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517694001,
#     'txId': 293618,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517694321}},
#  {'payload': {'after': {'address': '9100 Peatonal del Río, San Andrés Tlalamac, Guerrero - Mexico 80766',
#     'cell': '(641) 402 0299',
#     'date_of_birth': 506356886907000,
#     'email': 'eloisa.sotelo@example.com',
#     'gender': 'female',
#     'id': 1131,
#     'insertion_time': 1727516897695633,
#     'latitude': 25.299,
#     'longitude': 86.7783,
#     'name': 'Ms Eloisa Sotelo',
#     'phone': '(670) 642 8387',
#     'picture_url': 'https://randomuser.me/api/portraits/women/93.jpg',
#     'registered_date': 1297625693340000,
#     'timezone': 'Azores, Cape Verde Islands (Offset -1:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934080712,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934080368","70934080712"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516898356,
#     'txId': 293323,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516898882}},
#  {'payload': {'after': {'address': '9303 Mannerheimintie, Hämeenlinna, Central Ostrobothnia - Finland 44034',
#     'cell': '045-142-03-53',
#     'date_of_birth': -608715572218000,
#     'email': 'nella.seppanen@example.com',
#     'gender': 'female',
#     'id': 1144,
#     'insertion_time': 1727516983584205,
#     'latitude': -29.7492,
#     'longitude': 104.9891,
#     'name': 'Ms Nella Seppanen',
#     'phone': '03-043-454',
#     'picture_url': 'https://randomuser.me/api/portraits/women/6.jpg',
#     'registered_date': 1327369619545000,
#     'timezone': 'Mountain Time (US & Canada) (Offset -7:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934090384,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934090240","70934090384"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516984221,
#     'txId': 293355,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516984739}},
#  {'payload': {'after': {'address': '2580 Henrik Sørensens vei, Ydstebøhamn, Sogn og Fjordane - Norway 2939',
#     'cell': '96201517',
#     'date_of_birth': -136226355615000,
#     'email': 'hubert.haile@example.com',
#     'gender': 'male',
#     'id': 1230,
#     'insertion_time': 1727517588320031,
#     'latitude': 46.9666,
#     'longitude': -22.2701,
#     'name': 'Mr Hubert Haile',
#     'phone': '31529324',
#     'picture_url': 'https://randomuser.me/api/portraits/men/6.jpg',
#     'registered_date': 1019870614925000,
#     'timezone': 'Baghdad, Riyadh, Moscow, St. Petersburg (Offset +3:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967647976,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967647632","70967647976"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517588986,
#     'txId': 293581,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517589576}},
#  {'payload': {'after': {'address': '7513 Esplanade du 9 Novembre 1989, Versailles, Ariège - France 83409',
#     'cell': '06-48-50-15-59',
#     'date_of_birth': -785691740726000,
#     'email': 'eve.guillaume@example.com',
#     'gender': 'female',
#     'id': 1152,
#     'insertion_time': 1727517036193172,
#     'latitude': -16.3802,
#     'longitude': 122.3749,
#     'name': 'Ms Eve Guillaume',
#     'phone': '03-85-08-94-00',
#     'picture_url': 'https://randomuser.me/api/portraits/women/2.jpg',
#     'registered_date': 1123937593681000,
#     'timezone': 'Pacific Time (US & Canada) (Offset -8:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934098688,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934098344","70934098688"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517036901,
#     'txId': 293376,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517037452}},
#  {'payload': {'after': {'address': '7357 Target Road, Taupo, Marlborough - New Zealand 98618',
#     'cell': '(237)-105-1217',
#     'date_of_birth': 492104225185000,
#     'email': 'jacob.williams@example.com',
#     'gender': 'male',
#     'id': 1237,
#     'insertion_time': 1727517660654098,
#     'latitude': 53.0811,
#     'longitude': -131.633,
#     'name': 'Mr Jacob Williams',
#     'phone': '(059)-832-5509',
#     'picture_url': 'https://randomuser.me/api/portraits/men/13.jpg',
#     'registered_date': 1354761400807000,
#     'timezone': 'Western Europe Time, London, Lisbon, Casablanca (Offset 0:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967654336,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967654136","70967654336"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517661321,
#     'txId': 293604,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517661960}},
#  {'payload': {'after': {'address': '4171 Goethestraße, Neustadt an der Aisch, Sachsen - Germany 55113',
#     'cell': '0176-2595505',
#     'date_of_birth': -28759070819000,
#     'email': 'gernot.osterloh@example.com',
#     'gender': 'male',
#     'id': 1109,
#     'insertion_time': 1727516752704478,
#     'latitude': -50.3287,
#     'longitude': -61.2729,
#     'name': 'Mr Gernot Osterloh',
#     'phone': '0761-7504804',
#     'picture_url': 'https://randomuser.me/api/portraits/men/42.jpg',
#     'registered_date': 1587525042889000,
#     'timezone': 'Brazil, Buenos Aires, Georgetown (Offset -3:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917407200,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917405072","70917407200"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516753491,
#     'txId': 293268,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516753895}},
#  {'payload': {'after': {'address': '2575 Te Atatu Road, New Plymouth, Canterbury - New Zealand 33296',
#     'cell': '(427)-343-0640',
#     'date_of_birth': 413455274202000,
#     'email': 'vincent.zhang@example.com',
#     'gender': 'male',
#     'id': 1224,
#     'insertion_time': 1727517549243725,
#     'latitude': 54.0395,
#     'longitude': -65.1199,
#     'name': 'Mr Vincent Zhang',
#     'phone': '(194)-512-5230',
#     'picture_url': 'https://randomuser.me/api/portraits/men/32.jpg',
#     'registered_date': 1327676640844000,
#     'timezone': 'Atlantic Time (Canada), Caracas, La Paz (Offset -4:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967643456,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967643056","70967643456"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517549932,
#     'txId': 293566,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517550151}},
#  {'payload': {'after': {'address': '6532 Tunalı Hilmi Cd, Bartın, Muğla - Turkey 96172',
#     'cell': '(467)-406-7691',
#     'date_of_birth': -22439904270000,
#     'email': 'babur.bademci@example.com',
#     'gender': 'male',
#     'id': 1130,
#     'insertion_time': 1727516891252399,
#     'latitude': 69.2611,
#     'longitude': -70.8808,
#     'name': 'Mr Babür Bademci',
#     'phone': '(831)-730-7949',
#     'picture_url': 'https://randomuser.me/api/portraits/men/65.jpg',
#     'registered_date': 1110183506048000,
#     'timezone': 'Brazil, Buenos Aires, Georgetown (Offset -3:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934079920,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934079432","70934079920"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516891941,
#     'txId': 293320,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516892298}},
#  {'payload': {'after': {'address': '4290 Engelbrecht I Laan, Westhem, Noord-Brabant - Netherlands 5617 AM',
#     'cell': '(06) 24450102',
#     'date_of_birth': -238637834940000,
#     'email': 'devano.breugelmans@example.com',
#     'gender': 'male',
#     'id': 1146,
#     'insertion_time': 1727516996758685,
#     'latitude': 37.6984,
#     'longitude': -112.0354,
#     'name': 'Mr Devano Breugelmans',
#     'phone': '(034) 5728751',
#     'picture_url': 'https://randomuser.me/api/portraits/men/17.jpg',
#     'registered_date': 1585121396034000,
#     'timezone': 'Bangkok, Hanoi, Jakarta (Offset +7:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934091888,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934091544","70934091888"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516997511,
#     'txId': 293360,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516997711}},
#  {'payload': {'after': {'address': '7443 Drevelstraat, Benningbroek, Friesland - Netherlands 6848 GU',
#     'cell': '(06) 85244073',
#     'date_of_birth': -481171083909000,
#     'email': 'crijn.visscher@example.com',
#     'gender': 'male',
#     'id': 1261,
#     'insertion_time': 1727517818923729,
#     'latitude': 38.3069,
#     'longitude': -137.3463,
#     'name': 'Mr Crijn Visscher',
#     'phone': '(020) 9873389',
#     'picture_url': 'https://randomuser.me/api/portraits/men/76.jpg',
#     'registered_date': 1030882150531000,
#     'timezone': 'Beijing, Perth, Singapore, Hong Kong (Offset +8:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984415144,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984414640","70984415144"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517819792,
#     'txId': 293666,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517820492}},
#  {'payload': {'after': {'address': '1900 Calle del Pez, Arrecife, Islas Baleares - Spain 40454',
#     'cell': '684-329-486',
#     'date_of_birth': 925577081265000,
#     'email': 'aitor.fernandez@example.com',
#     'gender': 'male',
#     'id': 1111,
#     'insertion_time': 1727516765766657,
#     'latitude': -34.1206,
#     'longitude': -50.8499,
#     'name': 'Mr Aitor Fernández',
#     'phone': '913-213-777',
#     'picture_url': 'https://randomuser.me/api/portraits/men/32.jpg',
#     'registered_date': 1150733925354000,
#     'timezone': 'Central Time (US & Canada), Mexico City (Offset -6:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917408520,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917408120","70917408520"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516766501,
#     'txId': 293272,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516766828}},
#  {'payload': {'after': {'address': '9145 Jacobskerksteeg, Sevenum, Noord-Brabant - Netherlands 6045 EH',
#     'cell': '(06) 09134326',
#     'date_of_birth': -479738585272000,
#     'email': 'baris.ubachs@example.com',
#     'gender': 'male',
#     'id': 1114,
#     'insertion_time': 1727516786336278,
#     'latitude': 33.4501,
#     'longitude': -179.7558,
#     'name': 'Mr Baris Ubachs',
#     'phone': '(002) 3808243',
#     'picture_url': 'https://randomuser.me/api/portraits/men/81.jpg',
#     'registered_date': 1298744487706000,
#     'timezone': 'Tokyo, Seoul, Osaka, Sapporo, Yakutsk (Offset +9:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
# ...
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516945391,
#     'txId': 293341,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516945920}},
#  {'payload': {'after': {'address': '6080 Maple Ave, Flatrock, Northwest Territories - Canada O0H 1W3',
#     'cell': 'V71 P37-7277',
#     'date_of_birth': -670810196379000,
#     'email': 'alicia.lam@example.com',
#     'gender': 'female',
#     'id': 1099,
#     'insertion_time': 1727516681557258,
#     'latitude': -65.2409,
#     'longitude': 108.1302,
#     'name': 'Ms Alicia Lam',
#     'phone': 'O67 S84-7757',
#     'picture_url': 'https://randomuser.me/api/portraits/women/63.jpg',
#     'registered_date': 1350198358998000,
#     'timezone': 'Alaska (Offset -9:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917394376,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917394176","70917394376"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516682327,
#     'txId': 293241,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516682984}},
#  {'payload': {'after': {'address': '4453 Avenida de Burgos, Pamplona, Galicia - Spain 64802',
#     'cell': '661-031-660',
#     'date_of_birth': -174296295430000,
#     'email': 'ignacio.vazquez@example.com',
#     'gender': 'male',
#     'id': 1101,
#     'insertion_time': 1727516695439164,
#     'latitude': -30.7322,
#     'longitude': -152.5826,
#     'name': 'Mr Ignacio Vázquez',
#     'phone': '940-705-110',
#     'picture_url': 'https://randomuser.me/api/portraits/men/42.jpg',
#     'registered_date': 1183100253209000,
#     'timezone': 'Kabul (Offset +4:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917395808,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917395664","70917395808"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516696151,
#     'txId': 293246,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516696469}},
#  {'payload': {'after': {'address': '36 Dublin Road, Kildare, Kilkenny - Ireland 56282',
#     'cell': '081-575-6139',
#     'date_of_birth': 29054398786000,
#     'email': 'dwayne.jensen@example.com',
#     'gender': 'male',
#     'id': 1202,
#     'insertion_time': 1727517400978609,
#     'latitude': 2.6647,
#     'longitude': -1.416,
#     'name': 'Mr Dwayne Jensen',
#     'phone': '061-410-6417',
#     'picture_url': 'https://randomuser.me/api/portraits/men/7.jpg',
#     'registered_date': 1581178202070000,
#     'timezone': 'Pacific Time (US & Canada) (Offset -8:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70967624360,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70967624160","70967624360"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517402091,
#     'txId': 293509,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517402439}},
#  {'payload': {'after': {'address': '5916 Calle del Pez, Orense, Región de Murcia - Spain 32748',
#     'cell': '651-372-738',
#     'date_of_birth': 423632611703000,
#     'email': 'lidia.diez@example.com',
#     'gender': 'female',
#     'id': 1172,
#     'insertion_time': 1727517192079481,
#     'latitude': -37.0453,
#     'longitude': 142.0068,
#     'name': 'Mrs Lidia Diez',
#     'phone': '971-419-804',
#     'picture_url': 'https://randomuser.me/api/portraits/women/8.jpg',
#     'registered_date': 1049397504948000,
#     'timezone': 'Kathmandu (Offset +5:45)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70950855648,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70950855592","70950855648"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517192801,
#     'txId': 293431,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517193142}},
#  {'payload': {'after': {'address': '1202 Toftevej, Hurup Thy, Danmark - Denmark 19669',
#     'cell': '86983864',
#     'date_of_birth': -336752523117000,
#     'email': 'julie.nielsen@example.com',
#     'gender': 'female',
#     'id': 1158,
#     'insertion_time': 1727517076303224,
#     'latitude': -41.6597,
#     'longitude': 45.4465,
#     'name': 'Ms Julie Nielsen',
#     'phone': '51623451',
#     'picture_url': 'https://randomuser.me/api/portraits/women/83.jpg',
#     'registered_date': 1567140763718000,
#     'timezone': 'Almaty, Dhaka, Colombo (Offset +6:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934103160,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934102816","70934103160"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517077061,
#     'txId': 293391,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517077581}},
#  {'payload': {'after': {'address': '5177 Hooftweg, Blauwhuis, Friesland - Netherlands 5251 LQ',
#     'cell': '(06) 14357837',
#     'date_of_birth': 491345614952000,
#     'email': 'rinke.huurdeman@example.com',
#     'gender': 'male',
#     'id': 1258,
#     'insertion_time': 1727517798796645,
#     'latitude': 36.8262,
#     'longitude': -84.2538,
#     'name': 'Mr Rinke Huurdeman',
#     'phone': '(074) 8111078',
#     'picture_url': 'https://randomuser.me/api/portraits/men/51.jpg',
#     'registered_date': 1123902502788000,
#     'timezone': 'Kabul (Offset +4:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984412792,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984412648","70984412792"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517799411,
#     'txId': 293658,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517800115}},
#  {'payload': {'after': {'address': '9830 Udbyhøjvej, Nørrebro, Hovedstaden - Denmark 29563',
#     'cell': '55977776',
#     'date_of_birth': -438170058110000,
#     'email': 'astrid.larsen@example.com',
#     'gender': 'female',
#     'id': 1115,
#     'insertion_time': 1727516792857849,
#     'latitude': -44.9967,
#     'longitude': 71.6078,
#     'name': 'Ms Astrid Larsen',
#     'phone': '10795955',
#     'picture_url': 'https://randomuser.me/api/portraits/women/70.jpg',
#     'registered_date': 1180806190685000,
#     'timezone': 'Alaska (Offset -9:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917411672,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917411272","70917411672"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516793631,
#     'txId': 293283,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516794179}},
#  {'payload': {'after': {'address': '8016 Nowlin Rd, Warragul, Victoria - Australia 768',
#     'cell': '0490-098-469',
#     'date_of_birth': -651576277387000,
#     'email': 'francisco.morales@example.com',
#     'gender': 'male',
#     'id': 1156,
#     'insertion_time': 1727517062125600,
#     'latitude': -87.2335,
#     'longitude': -29.3683,
#     'name': 'Mr Francisco Morales',
#     'phone': '05-7635-4194',
#     'picture_url': 'https://randomuser.me/api/portraits/men/0.jpg',
#     'registered_date': 1279846790671000,
#     'timezone': 'Kabul (Offset +4:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934101528,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934101328","70934101528"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517062791,
#     'txId': 293385,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517063608}},
#  {'payload': {'after': {'address': '702 Oaks Cross, Durham, Grampian - United Kingdom P7E 8AX',
#     'cell': '07877 525516',
#     'date_of_birth': -651176338319000,
#     'email': 'faith.evans@example.com',
#     'gender': 'female',
#     'id': 1197,
#     'insertion_time': 1727517364377791,
#     'latitude': -6.5606,
#     'longitude': 160.3975,
#     'name': 'Mrs Faith Evans',
#     'phone': '01800 903679',
#     'picture_url': 'https://randomuser.me/api/portraits/women/48.jpg',
#     'registered_date': 1182543651330000,
#     'timezone': 'Kabul (Offset +4:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70950884016,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70950883616","70950884016"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517365562,
#     'txId': 293496,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517366073}},
#  {'payload': {'after': {'address': '4066 Sherborne Street, Timaru, Otago - New Zealand 33244',
#     'cell': '(958)-332-1833',
#     'date_of_birth': 359134325970000,
#     'email': 'ruby.chen@example.com',
#     'gender': 'female',
#     'id': 1151,
#     'insertion_time': 1727517029814232,
#     'latitude': 54.7771,
#     'longitude': 111.6767,
#     'name': 'Ms Ruby Chen',
#     'phone': '(263)-529-8026',
#     'picture_url': 'https://randomuser.me/api/portraits/women/70.jpg',
#     'registered_date': 1628134095003000,
#     'timezone': 'Hawaii (Offset -10:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934097912,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934097712","70934097912"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517030492,
#     'txId': 293373,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517030865}},
#  {'payload': {'after': {'address': '4543 Locust Rd, Memphis, North Carolina - United States 41371',
#     'cell': '(508) 965-7272',
#     'date_of_birth': 851996259536000,
#     'email': 'kay.may@example.com',
#     'gender': 'female',
#     'id': 1126,
#     'insertion_time': 1727516864939599,
#     'latitude': 86.0115,
#     'longitude': 52.1916,
#     'name': 'Ms Kay May',
#     'phone': '(906) 922-6211',
#     'picture_url': 'https://randomuser.me/api/portraits/women/28.jpg',
#     'registered_date': 1653067108240000,
#     'timezone': 'Alaska (Offset -9:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934076792,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934076448","70934076792"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516865621,
#     'txId': 293310,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516866137}},
#  {'payload': {'after': {'address': '187 Dundas Rd, Maidstone, Yukon - Canada X7B 6H3',
#     'cell': 'B17 L96-9222',
#     'date_of_birth': -798404519020000,
#     'email': 'noah.belanger@example.com',
#     'gender': 'male',
#     'id': 1260,
#     'insertion_time': 1727517812524309,
#     'latitude': -65.4499,
#     'longitude': -107.3806,
#     'name': 'Mr Noah Bélanger',
#     'phone': 'O79 B96-3981',
#     'picture_url': 'https://randomuser.me/api/portraits/men/65.jpg',
#     'registered_date': 1189255242627000,
#     'timezone': 'Kabul (Offset +4:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984414224,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984414024","70984414224"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517813142,
#     'txId': 293663,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517813594}},
#  {'payload': {'after': {'address': '6824 Åsensvingen, Skreia, Rogaland - Norway 6212',
#     'cell': '48046486',
#     'date_of_birth': -612142032166000,
#     'email': 'joar.ostrem@example.com',
#     'gender': 'male',
#     'id': 1106,
#     'insertion_time': 1727516733461964,
#     'latitude': 42.9541,
#     'longitude': -111.3543,
#     'name': 'Mr Joar Østrem',
#     'phone': '51310009',
#     'picture_url': 'https://randomuser.me/api/portraits/men/81.jpg',
#     'registered_date': 1522385313818000,
#     'timezone': 'Tehran (Offset +3:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70917399848,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70917399448","70917399848"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516734141,
#     'txId': 293260,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516734585}},
#  {'payload': {'after': {'address': '2410 Calle de Atocha, Mérida, Galicia - Spain 48961',
#     'cell': '664-862-612',
#     'date_of_birth': -405842991680000,
#     'email': 'joan.diaz@example.com',
#     'gender': 'male',
#     'id': 1254,
#     'insertion_time': 1727517771415916,
#     'latitude': -35.088,
#     'longitude': -179.8864,
#     'name': 'Mr Joan Diaz',
#     'phone': '940-805-259',
#     'picture_url': 'https://randomuser.me/api/portraits/men/20.jpg',
#     'registered_date': 1044692639621000,
#     'timezone': 'Alaska (Offset -9:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984409784,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984409584","70984409784"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517772071,
#     'txId': 293647,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517772291}},
#  {'payload': {'after': {'address': '1808 Rani No Hajiro, Gwalior, Gujarat - India 41052',
#     'cell': '8151759143',
#     'date_of_birth': -452289528580000,
#     'email': 'manthan.saha@example.com',
#     'gender': 'male',
#     'id': 1122,
#     'insertion_time': 1727516838956564,
#     'latitude': 11.9316,
#     'longitude': -93.5941,
#     'name': 'Mr Manthan Saha',
#     'phone': '9142912132',
#     'picture_url': 'https://randomuser.me/api/portraits/men/82.jpg',
#     'registered_date': 1143432210478000,
#     'timezone': 'Hawaii (Offset -10:00)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70934073760,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70934073704","70934073760"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727516839711,
#     'txId': 293299,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727516840163}},
#  {'payload': {'after': {'address': '9814 Ratha Bheedi, Gangtok, Jharkhand - India 95053',
#     'cell': '9927767950',
#     'date_of_birth': -704845967280000,
#     'email': 'ekapad.saniel@example.com',
#     'gender': 'male',
#     'id': 1259,
#     'insertion_time': 1727517806073036,
#     'latitude': 4.2987,
#     'longitude': -177.5649,
#     'name': 'Mr Ekapad Saniel',
#     'phone': '9864337169',
#     'picture_url': 'https://randomuser.me/api/portraits/men/48.jpg',
#     'registered_date': 1382734342148000,
#     'timezone': 'Kabul (Offset +4:30)'},
#    'before': None,
#    'op': 'c',
#    'source': {'connector': 'postgresql',
#     'db': 'airflowdatabaseflexible',
#     'lsn': 70984413616,
#     'name': 'fabric_deb_conn',
#     'schema': 'fabric',
#     'sequence': '["70984413216","70984413616"]',
#     'snapshot': 'false',
#     'table': 'user_data',
#     'ts_ms': 1727517806791,
#     'txId': 293661,
#     'version': '2.2.1.Final',
#     'xmin': None},
#    'transaction': None,
#    'ts_ms': 1727517807204}}]

# %%
@sequence_mapper("Step 3")
def parse_payload(payload_array: List):
    """
    Parses a list of payload dictionaries to extract main information.

    This function iterates over the provided list of payloads, attempting to 
    extract the "after" portion of the payload. If a KeyError occurs (i.e., 
    the expected structure is not present), the function will skip that payload.

    Parameters:
    payload_array (List): A list of dictionaries representing the payload data.

    Returns:
    List: A list of dictionaries containing the parsed main information from 
          each payload, with each dictionary representing the "after" data.
    """
    parsed_payload = []

    for payload in payload_array:
        try:
            main_info: Dict = payload["payload"]["after"]
        except KeyError:
            continue
        
        parsed_payload.append(main_info)

    return parsed_payload

parsed_payload: List = parse_payload(payload_array)
parsed_payload[0]
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 7, Finished, Available, Finished)
# Flatten the payload
# {'address': '3973 دکتر لواسانی, ایلام, آذربایجان شرقی - Iran 86952',
#  'cell': '0943-252-6704',
#  'date_of_birth': 201271548020000,
#  'email': 'yly.qsmy@example.com',
#  'gender': 'male',
#  'id': 1140,
#  'insertion_time': 1727516957704587,
#  'latitude': 15.2516,
#  'longitude': -101.2421,
#  'name': 'Mr ایلیا قاسمی',
#  'phone': '023-98186430',
#  'picture_url': 'https://randomuser.me/api/portraits/men/87.jpg',
#  'registered_date': 1353356496219000,
#  'timezone': 'Newfoundland (Offset -3:30)'}

# %%
def create_schema()-> StructType:
    """
    Creates and returns a Spark DataFrame schema.

    This function defines the structure of the DataFrame by specifying the 
    column names and their corresponding data types. The schema includes 
    fields for personal information such as name, gender, address, 
    and various timestamps.

    Returns:
    StructType: A StructType object representing the schema of the DataFrame, 
                which includes the following fields:
                - name (StringType)
                - gender (StringType)
                - id (StringType)
                - address (StringType)
                - timezone (StringType)
                - email (StringType)
                - phone (StringType)
                - cell (StringType)
                - date_of_birth (LongType)
                - registered_date (LongType)
                - picture_url (StringType)
                - insertion_time (LongType)
                - latitude (DoubleType)
                - longitude (DoubleType)
    """
    
    schema = StructType([
        StructField("name", StringType(), True),
        StructField("gender", StringType(), True),
        StructField("id", StringType(), True),
        StructField("address", StringType(), True),
        StructField("timezone", StringType(), True),
        StructField("email", StringType(), True),
        StructField("phone", StringType(), True),
        StructField("cell", StringType(), True),
        StructField("date_of_birth", LongType(), True),
        StructField("registered_date", LongType(), True),
        StructField("picture_url", StringType(), True),
        StructField("insertion_time", LongType(), True),
        StructField("latitude", DoubleType(), True),
        StructField("longitude", DoubleType(), True)
        ])

    return schema


@sequence_mapper("Step 4")
def create_dataframe_from_parsed_payload(parse_payload: List, schema_maker: Callable[[], DataFrame] = create_schema())-> DataFrame:
    """
    Creates a Spark DataFrame from a parsed payload using a specified schema.

    This function takes a list of parsed payloads and a callable schema maker 
    function to create a DataFrame. The schema maker should return a StructType 
    defining the structure of the DataFrame.

    Parameters:
    parse_payload (List): A list of dictionaries containing the parsed payload data.
    schema_maker (Callable[[], DataFrame]): A callable that returns a DataFrame schema.

    Returns:
    DataFrame: A Spark DataFrame created from the parsed payload and schema.
    """
    parsed_df = spark.createDataFrame(parsed_payload, schema_maker)
    return parsed_df

parsed_df = create_dataframe_from_parsed_payload(parsed_payload, create_schema())
display(parsed_df)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 8, Finished, Available, Finished)
# Creating input DataFrame
# SynapseWidget(Synapse.DataFrame, 55000faa-a037-4855-9e84-2d951f067850)

# %%
@sequence_mapper("Step 5")
def capitalize_columns(df: DataFrame)-> DataFrame:
    """
    Capitalizes the names of all columns in a Spark DataFrame.

    This function iterates over the columns of the input DataFrame and modifies 
    their names to be capitalized.

    Parameters:
    df (DataFrame): The input Spark DataFrame whose columns are to be capitalized.

    Returns:
    DataFrame: A new Spark DataFrame with capitalized column names.
    """

    for col in df.columns:
        df = df.toDF(*[col.capitalize() for col in df.columns])

    return df

transform_df: DataFrame = capitalize_columns(parsed_df)
display(transform_df)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 9, Finished, Available, Finished)
# Capitalize column names
# SynapseWidget(Synapse.DataFrame, 994161d0-bd7a-43f2-952e-c744978157c1)

# %%
@sequence_mapper("Step 6")
def parse_timestamp(df: DataFrame, column_name: str, date_only: bool = False, time_scale: int = 1_000_000_000)-> DataFrame:
    """
    Parses a timestamp column in a Spark DataFrame.

    This function updates the specified column in the DataFrame by converting 
    its values from a Unix timestamp format. If the `date_only` parameter is 
    set to True, the column will be cast to a date type.

    Parameters:
    df (DataFrame): The input Spark DataFrame containing the timestamp column.
    column_name (str): The name of the column to be parsed.
    date_only (bool, optional): If True, the column will be cast to date type. 
                                 Defaults to False.
    time_scale (int, optional): A factor to scale the timestamp values. 
                                 Defaults to 1,000,000,000.

    Returns:
    DataFrame: A Spark DataFrame with the updated timestamp column.
    """
    print(f"Timestamp column: {column_name}")
    # Update the existing column with the parsed timestamp
    df = df.withColumn(column_name, from_unixtime(col(column_name) / time_scale))
    
    if date_only:
        # Cast the updated column to date type
        df = df.withColumn(column_name, col(column_name).cast("date"))
    
    return df


transform_df: DataFrame = parse_timestamp(transform_df, "Insertion_time", date_only=False)
transform_df: DataFrame = parse_timestamp(transform_df, "Registered_date", date_only=True)
transform_df: DataFrame = parse_timestamp(transform_df, "Date_of_birth", date_only=True)

display(transform_df)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 10, Finished, Available, Finished)
# Convert Timestamp column to Date and/or Datetime
#
# Timestamp column: Insertion_time
# Convert Timestamp column to Date and/or Datetime
#
# Timestamp column: Registered_date
# Convert Timestamp column to Date and/or Datetime
#
# Timestamp column: Date_of_birth
# SynapseWidget(Synapse.DataFrame, fddb611e-d73d-443d-90f0-4b9e5e2d28af)

# %%
@sequence_mapper("Step 7")
def split_timezone(df: DataFrame)-> DataFrame:
    """
    Splits the timezone column into separate location and offset columns.

    This function extracts the timezone location and offset from a 
    formatted timezone string in the DataFrame. The original timezone 
    column is removed after extraction.

    Parameters:
    df (DataFrame): The input Spark DataFrame containing the timezone column.

    Returns:
    DataFrame: A Spark DataFrame with the timezone split into separate 
                "Timezone_location" and "Timezone_offset" columns.
    """
    split_timezone = F.split(df["Timezone"], "\(Offset")
    

    df = df.withColumn("Timezone_location", split_timezone.getItem(0)) \
           .withColumn("Timezone_offset", split_timezone.getItem(1)) \

    remove_bracket = F.regexp_replace("Timezone_offset", r"\)", "")
    df = df.withColumn("Timezone_offset", remove_bracket)

    df = df.drop("Timezone")
    return df

transform_df: DataFrame = split_timezone(transform_df)
display(transform_df)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 11, Finished, Available, Finished)
# Extract and Create Timezone Location and offset from GMT fields
# SynapseWidget(Synapse.DataFrame, 110bba1e-a0da-41ff-8f00-f1e95b555bce)

# %%
@sequence_mapper("Step 8")
def timezone_hours_from_gmt(df: DataFrame, offset_column: str, output_col: str)->DataFrame:
    """
    Converts a GMT offset string to total hours and adds it as a new column.

    This function defines a helper function to calculate the total hours from a 
    GMT offset string (formatted as "+hh:mm" or "-hh:mm") and applies it to the 
    specified offset column. The result is added as a new column in the DataFrame.

    Parameters:
    df (DataFrame): The input Spark DataFrame containing the GMT offset column.
    offset_column (str): The name of the column with GMT offset strings.
    output_col (str): The name of the new column to store the total hours.

    Returns:
    DataFrame: A Spark DataFrame with an additional column containing the 
                total hours derived from the GMT offset.
    """
    
    def calculate_offset_in_hours(offset: str) -> float:
        # Determine the sign
        sign = 1.0 if offset.strip().startswith('+') else -1.0
        # Extract hours and minutes without the sign
        hours, minutes = map(int, offset.strip().strip("-").strip("+").split(':'))
        # Calculate total hours
        total_hours = sign * (hours + minutes/60.0)
        return total_hours

    # Register the UDF
    calculate_offset_udf = udf(calculate_offset_in_hours, DoubleType())

    # Apply the UDF to create a new column with the total minutes offset
    df = transform_df.withColumn(output_col, calculate_offset_udf(col(offset_column)))

    return df

transform_df: DataFrame = timezone_hours_from_gmt(transform_df, "Timezone_offset", "Hours_from_gmt")
display(transform_df)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 12, Finished, Available, Finished)
# Create float field from GMT offset field
# SynapseWidget(Synapse.DataFrame, a81331c9-4a58-42c3-ac78-61b85c009aa1)

# %%
@sequence_mapper("Step 9")
def extract_age(df: DataFrame, date_column: str)-> DataFrame:
    """
    Calculates the age based on a date column and adds it as a new column.

    This function converts the specified date column to a date type, calculates 
    the age in years based on the current date, and adds a new column named "Age" 
    to the DataFrame.

    Parameters:
    df (DataFrame): The input Spark DataFrame containing the date column.
    date_column (str): The name of the column to be used for age calculation.

    Returns:
    DataFrame: A Spark DataFrame with an additional "Age" column containing 
                the calculated ages.
    """
    
    df = df.withColumn(date_column, col(date_column).cast("date"))

    # Calculate the age
    df = df.withColumn("Age", floor(datediff(current_date(), col(date_column)) / 365.25))

    return df

transform_df: DataFrame = extract_age(transform_df, "Date_of_birth")
display(transform_df)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 13, Finished, Available, Finished)
# Extract and Create the Ages field
# SynapseWidget(Synapse.DataFrame, b206c616-3058-497c-a4f9-67637ed12b6b)

# %%
@sequence_mapper("Step 10")
def final_cleanup(df: DataFrame, cols: list)->DataFrame:
    """
    Performs final cleanup on the DataFrame by selecting specified columns 
    and adding an ingestion date.

    This function selects the columns specified in the `cols` list and adds a 
    new column named "Ingestion_Date" with the current timestamp.

    Parameters:
    df (DataFrame): The input Spark DataFrame to be cleaned.
    cols (list): A list of column names to retain in the cleaned DataFrame.

    Returns:
    DataFrame: A Spark DataFrame containing only the specified columns along 
                with the "Ingestion_Date" column.
    """

    df = df.select(*cols)

    df = df.withColumn("Ingestion_Date", F.lit(datetime.now()))
    return df


ordered_columns = ["Name", "Gender", "Id", "Age", "Date_of_birth", "Address", "Timezone_location", "Timezone_offset", "Hours_from_gmt",
 "Longitude", "Latitude", "Cell", "Phone", "Email", "Registered_date", "Picture_url", "Insertion_time"]

transform_df: DataFrame = final_cleanup(transform_df, ordered_columns)

display(transform_df)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 14, Finished, Available, Finished)
# Reorder the columns and add Ingestion Date field
# SynapseWidget(Synapse.DataFrame, ec0068ee-c110-4ee2-9c31-0d195c0a6148)

# %%
@sequence_mapper("Step 11")
def write_to_delta(*, df: DataFrame, table_name: str)-> None:
    """
    Writes the provided DataFrame to a specified Delta table.

    This function saves the input DataFrame to a Delta table with the 
    specified name, using the "overwrite" mode to replace any existing 
    data in the table.

    Parameters:
    df (DataFrame): The Spark DataFrame to be written to the Delta table.
    table_name (str): The name of the Delta table where the DataFrame 
                      will be saved.

    Returns:
    None: This function does not return a value but prints a confirmation 
          message upon successful writing to the table.
    """

    df.write.format("delta").mode("overwrite").saveAsTable(table_name)
    print(f"Data successfully written to {table_name}")

table_name = "user_data"
write_to_delta(df = transform_df, table_name = table_name)
# Out:
# StatementMeta(, ce70ca6f-88e6-4362-adf8-ab7e5f4124a9, 15, Finished, Available, Finished)
# Writing the cleaned dataframe to Delta Table
# Data successfully written to user_data

# %% [markdown]
# ### Run sequence
# Here, we apply all the functions we defined earlier. All transformations of `JSON` data from **Ingestion** to **Upload** to Delta Table is done in this sequence.

# %%
# Read the JSON files from the "user_folder"
abfss_path = "abfss://fabric_cdc@onelake.dfs.fabric.microsoft.com/cdc_lakehouse.Lakehouse/Files/user_folder"
df = read_data(abfss_path)

# Extract the payload from the input dataframe df
payload_array: List = extract_payload(df)

# Flatten the payload and create a dataframe with all the required fields
parsed_payload: List = parse_payload(payload_array)
parsed_df = create_dataframe_from_parsed_payload(parsed_payload, create_schema())

# Capitalize the column names
transform_df: DataFrame = capitalize_columns(parsed_df)

# Convert Insertion_time, Registered_date, and Date_of_birth fields from Timestamp to Date and/or Datetime values
transform_df: DataFrame = parse_timestamp(transform_df, "Insertion_time", date_only=False)
transform_df: DataFrame = parse_timestamp(transform_df, "Registered_date", date_only=True)
transform_df: DataFrame = parse_timestamp(transform_df, "Date_of_birth", date_only=True)

# Split the Timezone location from the Timezone offset and derive number of hours from GMT
transform_df: DataFrame = split_timezone(transform_df)
transform_df: DataFrame = timezone_hours_from_gmt(transform_df, "Timezone_offset", "Hours_from_gmt")

# Extract the Age from the Date_of_birth column
transform_df: DataFrame = extract_age(transform_df, "Date_of_birth")

# Reorder the columns and add an Ingestion_date.
ordered_columns = ["Name", "Gender", "Id", "Age", "Date_of_birth", "Address", "Timezone_location", "Timezone_offset", "Hours_from_gmt",
 "Longitude", "Latitude", "Cell", "Phone", "Email", "Registered_date", "Picture_url", "Insertion_time"]

transform_df: DataFrame = final_cleanup(transform_df, ordered_columns)

# Write the transformed DataFrame to Delta table
table_name = "user_data"
write_to_delta(df = transform_df, table_name = table_name)
# Out:
# StatementMeta(, e5546cb7-215e-4773-94bb-209ae0b541f6, 24, Finished, Available, Finished)
# Read the JSON data from Abfss filepath as Complex Dataframe
#
# Extracting payload
#
# Flatten the payload
#
# Creating input DataFrame
#
# Capitalize column names
#
# Convert Timestamp column to Date and/or Datetime
#
# Timestamp column: Insertion_time
# Convert Timestamp column to Date and/or Datetime
#
# Timestamp column: Registered_date
# Convert Timestamp column to Date and/or Datetime
#
# Timestamp column: Date_of_birth
# Extract and Create Timezone Location and offset from GMT fields
#
# Create float field from GMT offset field
#
# Extract and Create the Ages field
#
# Reorder the columns and add Ingestion Date field
#
# Writing the cleaned dataframe to Delta Table
# Data successfully written to user_data

# %%
display(transform_df)
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# SynapseWidget(Synapse.DataFrame, a3e1a4a9-9c7d-4717-8cd0-e7cbcfbbae98)
